# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer

# %%
# Read in the data
df = pd.read_csv('mat,wagonremoved.csv', header=0)

# %%
df
# Out:
#      SNO      Mat Code   Heat No          Wagon No
# 0      1  4.713100e+14  23F01059  SER55070161847
# 1      2  4.713100e+14  23F01058  SER55070161847
# 2      3  4.713100e+14  23F01058  SER55070161847
# 3      4           NaN  23F01035  NCR94131810560
# 4      5  4.713100e+14       NaN  NCR94131810560
# ..   ...           ...       ...               ...
# 479  480           NaN   2303299  NCR94131363349
# 480  481  1.512000e+14   2303299  NCR94131363349
# 481  482  1.512000e+14       NaN  NCR94131363349
# 482  483  1.512000e+14   2303299  NCR94131363349
# 483  484  1.512000e+14   2303299  NCR94131363349
#
# [484 rows x 4 columns]

# %%
# Identify missing heat no values
heat_no_missing = df[df['Heat No'].isna()]

# %%
heat_no_missing
# Out:
#      SNO      Mat Code Heat No          Wagon No
# 4      5  4.713100e+14     NaN  NCR94131810560
# 12    13  4.713100e+14     NaN  NCR94131810560
# 19    20  4.713100e+14     NaN  ECOR56120642279
# 31    32  1.512000e+14     NaN  SCR57091810261
# 37    38           NaN     NaN  SER94072310525
# 41    42  1.512000e+14     NaN  SER94072310525
# 46    47  4.713100e+14     NaN  ECOR94122111607
# 48    49  4.713100e+14     NaN  ECOR94122111607
# 53    54  4.713100e+14     NaN  ECOR94122111607
# 59    60  4.713100e+14     NaN  NER55040260488
# 64    65  4.713100e+14     NaN  NER55040260488
# 77    78  1.512000e+14     NaN  SCR94091710115
# 79    80  1.512000e+14     NaN  SCR94091710115
# 88    89  4.713100e+14     NaN  ER55020120351
# 89    90  4.713100e+14     NaN  ER55020120351
# 108  109  1.512000e+14     NaN  SER55079960861
# 119  120  4.713100e+14     NaN  SER94072310532
# 124  125  4.713100e+14     NaN  SER94072310532
# 126  127  4.713100e+14     NaN  SER94072310532
# ...

# %%
# Fill missing heat no values with most frequent value 
df['Heat No'] = df['Heat No'].fillna('missing')

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
df['Heat No'] = pd.to_numeric(df['Heat No'], errors='coerce')

# %%
imputer = SimpleImputer(strategy='most_frequent')

# %%
heat_no_numeric = df[pd.to_numeric(df['Heat No'], errors='coerce').notnull()]
imputer.fit(heat_no_numeric[['Heat No']])
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
heat_no_notnull = df[df['Heat No'].notnull()]
imputer.fit(heat_no_notnull[['Heat No']])
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
# Identify missing mat code values
mat_code_missing = df[df['Mat Code'].isna()]

# %%
# Fill missing mat code values with most frequent value
imputer.fit(df[['Mat Code']])
mat_code_filled = imputer.transform(mat_code_missing[['Mat Code']])

# %%
df['Heat No'] = df['Heat No'].fillna('MISSING')

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
df = df[df['Heat No'].notna()]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 4
#       2 imputer = SimpleImputer(missing_values=None, strategy='most_frequent')
#       3 imputer.fit(df[['Heat No']])
# ----> 4 heat_no_filled = imputer.transform(heat_no_missing[['Heat No']])
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# ...
